# %% [markdown]
# File for comparing feature representation from baseline models with ornet's representation. For now, use neelima's experiment, so compare new representations with old through RF, Decision Tree and KNN
#
#
# ### Global images
#
#
# ### ROI images

# %%
import os
import numpy as np
import pickle
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier

# %%
with open('/home/rachel/ornet/representations/roi_feat.pkl', 'rb') as f:
            feature_df = pickle.load(f)

# %%
feature_df
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.219869  2.265010  0.149717  0.275523  0.695949  1.817426 -0.014663
# 1  -0.677430 -2.961776  6.312088  2.433789 -3.508028 -0.800710 -0.534342
# 2   0.157562 -6.245750  4.057928  3.053822 -5.598476 -2.790022 -1.477918
# 3   0.442069  0.295920 -1.003968  0.082024 -0.429495  0.196706 -0.494045
# 4   0.358467  0.079643  1.046432  1.199571 -1.560748  1.062460 -0.607668
# ..       ...       ...       ...       ...       ...       ...       ...
# 1   0.063207  0.403372  1.604965  0.954122 -0.764626  0.833775 -0.412412
# 2   0.295395 -0.327515  0.572441  0.898187 -1.296497  0.194545 -0.565282
# 3  -0.281319 -2.343976  4.330209  1.876811 -2.789436 -0.612913 -0.565294
# 4  -0.012328 -0.832143  2.080678  1.041733 -1.594684 -0.035330 -0.514875
# 0   0.800106  0.488818 -1.804613  0.323965 -0.592586  0.988817 -0.744739
#
#            7         8         9  label
# 0  -1.494378 -0.673682  2.234436      0
# ...

# %%
X = feature_df.iloc[:,:-1]
y = feature_df['label']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.2,  random_state=73, shuffle=True, stratify=None)

# %%
clf = RandomForestClassifier(max_depth=3, random_state=0)
clf.fit(X_train, y_train)
pred = clf.predict(X_test)
accuracy = np.sum(pred == y_test) / len(y_test)
print("RF accuracy:", accuracy)

clf =  KNeighborsClassifier(n_neighbors=3)
clf.fit(X_train, y_train)
pred = clf.predict(X_test)
accuracy = np.sum(pred == y_test) / len(y_test)
print("KNN accuracy", accuracy)

clf =  tree.DecisionTreeClassifier()
clf.fit(X_train, y_train)
pred = clf.predict(X_test)
accuracy = np.sum(pred == y_test) / len(y_test)
print("Decision Tree Accuracy", accuracy)
# Out:
# RF accuracy: 0.6086956521739131
# KNN accuracy 0.6521739130434783
# Decision Tree accuracy 0.6086956521739131

# %%
with open('/home/rachel/ornet/representations/roi_feat.pkl', 'rb') as f:
            feature_df = pickle.load(f)

X = feature_df.iloc[:,:-1]
y = feature_df['label']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.2,  random_state=73, shuffle=True, stratify=None)

# %%
clf = RandomForestClassifier(max_depth=3, random_state=0)
clf.fit(X_train, y_train)
pred = clf.predict(X_test)
accuracy = np.sum(pred == y_test) / len(y_test)
print("RF accuracy:", accuracy)

clf =  KNeighborsClassifier(n_neighbors=3)
clf.fit(X_train, y_train)
pred = clf.predict(X_test)
accuracy = np.sum(pred == y_test) / len(y_test)
print("KNN accuracy", accuracy)

clf =  tree.DecisionTreeClassifier()
clf.fit(X_train, y_train)
pred = clf.predict(X_test)
accuracy = np.sum(pred == y_test) / len(y_test)
print("Decision Tree accuracy", accuracy)
# Out:
# RF accuracy: 0.9565217391304348
# KNN accuracy 0.9130434782608695
# Decision Tree accuracy 0.8695652173913043
